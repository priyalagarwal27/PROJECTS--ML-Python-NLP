# %%
# Basic Libraries
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# Data Visualization Libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Displaying all the columns and rows
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df=pd.read_excel('customer_retention_dataset.xlsx')

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %% [markdown]
# ### No. of Rows and No. of columns

# %%
print("No. of rows = ", df.shape[0])
print("No. of columns = ", df.shape[1])
# Out:
# No. of rows =  269
# No. of columns =  71

# %% [markdown]
# ### Information about data types of each column

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %% [markdown]
# ### Rows having all missing values

# %%
# Row indexes of empty rows
print("Row indexes of empty rows : ", df[df.isnull().all(axis =1)].index.tolist())
# Out:
# Row indexes of empty rows :  []

# %%
#Checking the missing values in data set
df.isnull().values.any()
# Out:
# False

# %%
#Checking the shape of the dataset
df.shape
# Out:
# (269, 71)

# %%
#Checking the datatype of the columns
df.dtypes
# Out:
# 1Gender of respondent                                                                                                                                                                                                  object
# 2 How old are you?                                                                                                                                                                                                     object
# 3 Which city do you shop online from?                                                                                                                                                                                  object
# 4 What is the Pin Code of where you shop online from?                                                                                                                                                                   int64
# ...

# %% [markdown]
# #### Observation:
#
# 1. No null value present in any rows.
# 2. All features are object datatype except Pin-code feature.

# %%
#Seeing the missing values via visualization
plt.figure(figsize=(22,8))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='coolwarm')
plt.show()

# %%
#Seprate the categorical columns and Numerical columns
cat_df,num_df=[],[]

for i in df:
    if df[i].dtype=='O':
        cat_df.append(i)
    elif (df[i].dtypes=='int64') | (df[i].dtypes=='float64') | (df[i].dtypes=='int32'):
        num_df.append(i)
    else: continue
        
print('>>> Total Number of Feature::', df.shape[1])
print('>>> Number of categorical features::', len(cat_df))
print('>>> Number of Numerical Feature::', len(num_df))
# Out:
# >>> Total Number of Feature:: 71
# >>> Number of categorical features:: 70
# >>> Number of Numerical Feature:: 1

# %%
#Univariate analysis of categorical features
for i in cat_df:
    f=plt.figure(figsize=(16,3))
    f.add_subplot(1,1,1)
    sns.countplot(df[i])

# %% [markdown]
# #### Observations:
#
# 1. Females are more as compared to males in Dataset.
# 2. Age between 21 to 50 years are more likely to search and buy online product.
# 3. Delhi as a metropolition city for online shopping is maximum but in Gurgaon online shopping is less than Ghaziabad,Solan,Kamal and Noida.
# 4. More than 4 years for Shopping online is longest period in the dataset.
# 5. Online purchase is less than 10 product is maximum means in the offer day and requirement of the product than buy the product.
# 6. 30 to 40 item purchase online in the dataset is also more means generally maximum person go for online product.
# 7. Using mobile internet for shopping online prodcut is more and Dial Up is very less.
# 8. Smart Phone and Laptop devices are mostly using for online shopping.
# 8. Windows operating system based mobile and laptop is used maximum time as compared to IOS and android for online shopping.
# 9. Google Chrome browser is widely used to access the website as compare to other browser.
# 10. Search engine is useful for the first time for the customer.
# 11. After first visit, E-mail and social media is not a better option for reaching online store directly whereas use of Application ,Direct url and serach engine is better.
# 12. More than 15 min is sufficient for making a purchase decision.
# 13. For Payment Option customer uses credit/debit card and cash on delivery(COD) as compared to E-Wallets option.
# 14. If Customer make mindset for buying product so generally payment of the product is done at same time very less chance go without payment.
# 15. If Customer finds better alternative offer at some other online shop for same product than maximum chance is to leave without payment.
# 16. Content of the website or Product is easy to read and understandable for customer to increase chance for online shopping.
# 17. For similar product one highlighted is very important for customer for buying product using comparison.
# 18. Before purchasing the product, customer read the complete information about listed seller and product detail.
#     So complete product detail and seller informatiom is very useful factor in online shopping.
# 19. Navigation of the website is also good for online shopping of the customer.
# 20. Loading and processing speed is very less than customer leave the website and no chance to come again for shopping.
# 21. User friendly website is also important factor for retention of customer.
# 22. Payment option is also convenient.
# 23. Privacy of the customer is also important for customer or online shopping.
# 24. If different communication channel is provided by Online shopping than maximum chance of retention of the customer.
# 25. Online shopping provides benefit and discount in the product to customer for again buying the product from online shops.
# 26. For purchasing any product decision of return and replacement policy is very important for online shopping if policy is avalable than customer purchase the product.
# 27. Quality information is provided for satisfaction of customer.
# 28. If user satisfy with the application or website of online shopping then they use it repeatedly and didn't go anywhere.
# 29. User satisfaction cannot exist without trust so trust is an important factor to buildup in online shopping.
# 30. Offering a wide range of product in several category for user then there is a maximum chance for customer to buy that    product and trust in online shopping.

# %% [markdown]
# ### From above data analysis we observe that from feature 1 to 47 generally gives the idea for growing online shop and Customer behaviour for online shopping .In this we also observed E-retail factors for customer activation and retention.

# %% [markdown]
# ### Based on features from 1 to 47 we have to do more data analysis by using graphical visualisation.

# %%
#Reliability of the website or application
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sns.countplot(x='Reliability of the website or application', data=df,palette='winter')

plt.title('Reliability of the website or application',fontsize=18)
plt.show()

# %% [markdown]
# ##### Observation:
#        Amazon and Flipkart are most Reliable Application.

# %%
#Wide variety of product on offers.
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sns.countplot(x='Wild variety of product on offer', data=df,palette='YlGn')

plt.title('Wild variety of product on offer',fontsize=18)
plt.show()

# %% [markdown]
# ##### Observation:
#         Amazon and Flipkart provides wide variety of products.

# %%
#Visual appealing web-page layout.
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sns.countplot(x='Visual appealing web-page layout', data=df)

plt.title('Visual appealing web-page layout',fontsize=18)
plt.show()

# %%
#Easy to use website or application
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sns.countplot(x='Easy to use website or application', data=df,palette='coolwarm')

plt.title('Easy to use website or application',fontsize=18)
plt.show()

# %% [markdown]
# ##### Observation:
#         Amazon and Flipkart is easy to use wensite and application.

# %%
#Speed of website and application 
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sns.countplot(x='Fast loading website speed of website and application', data=df,palette='magma')

plt.title('Fast loading website speed of website and application',fontsize=18)
plt.show()

# %%
#Payment options available 
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sns.countplot(x='Availability of several payment options', data=df)

plt.title('Availability of several payment options',fontsize=18)
plt.show()

# %% [markdown]
# ##### Observation:
#         Amazon and Flipkart has more payment options than others available at there website and applications.

# %%
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sns.countplot(x='Perceived Trustworthiness', data=df,palette='rainbow')

plt.title('Perceived Trustworthiness',fontsize=18)
plt.show()

# %% [markdown]
# ##### Observation:
#         Amazon is more trustworthy website for online shopping for customer than others.

# %%
#Privacy of customers’ information.
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sns.countplot(x='Privacy of customers’ information', data=df,palette='rocket')

plt.title('Privacy of customers’ information',fontsize=18)
plt.show()

# %% [markdown]
# ##### Observation:
#         Amazon maintains more privacy of the customer information than flipKart.

# %%
#Quickness to complete purchase
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sns.countplot(x='Quickness to complete purchase', data=df,palette='PuRd')

plt.title('Quickness to complete purchase',fontsize=18)
plt.show()

# %%
#Complete, relevant description information of products.
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sns.countplot(x='Complete, relevant description information of products', data=df,palette='inferno')

plt.title('Complete, relevant description information of products',fontsize=18)
plt.show()

# %% [markdown]
# ##### Observation:
#         Amazon and Flipkart provide the complete Imformation about Product.

# %%
#Customer financial information.
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sns.countplot(x='Security of customer financial information', data=df,palette='tab10')

plt.title('Security of customer financial information',fontsize=18)
plt.show()

# %% [markdown]
# ##### Observation:
#         Customer Financial Information is more secure in Amazon.

# %%
#Presence of online assistance through multi-channel
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sns.countplot(x='Presence of online assistance through multi-channel', data=df,palette='prism')

plt.title('Presence of online assistance through multi-channel',fontsize=18)
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sns.countplot(x='Longer time to get logged in (promotion, sales period)', data=df,palette='magma')

plt.title('Longer time to get logged in (promotion, sales period)',fontsize=18)
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sns.countplot(x='Frequent disruption when moving from one page to another', data=df,palette='Wistia')

plt.title('Frequent disruption when moving from one page to another',fontsize=18)
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sns.countplot(x='Longer time in displaying graphics and photos (promotion, sales period)', data=df,palette='brg_r')

plt.title('Longer time in displaying graphics and photos (promotion, sales period)',fontsize=18)
plt.show()

# %%
#Delivery period
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sns.countplot(x='Longer delivery period', data=df,palette='hot_r')

plt.title('Longer delivery period',fontsize=18)
plt.show()

# %% [markdown]
# ##### Observation:
#         Paytm and Snapdeal takes longer time in delivery of products as compared to Amazon and Flipkart online shop .

# %%
#Late declaration of Price
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sns.countplot(x='Late declaration of price (promotion, sales period)', data=df,palette='cool')

plt.title('Late declaration of price (promotion, sales period)',fontsize=18)
plt.show()

# %% [markdown]
# ##### Observation:
#         Myntra declares late for price of products .

# %%
#Longer page loading time
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sns.countplot(x='Longer page loading time (promotion, sales period)', data=df,palette='PuOr')

plt.title('Longer page loading time (promotion, sales period)',fontsize=18)
plt.show()

# %% [markdown]
# ##### Observation:
#         Myntra and Paytm takes longer time in loading page.

# %%
#Limited mode of payment
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sns.countplot(x='Limited mode of payment on most products (promotion, sales period)', data=df,palette='Paired')

plt.title('Limited mode of payment on most products (promotion, sales period)',fontsize=18)
plt.show()

# %% [markdown]
# ##### Observation:
#         Snapdeal has limited mode of payment as compared to others website.

# %%
#Change in website/Application design
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sns.countplot(x='Change in website/Application design', data=df,palette='Reds')

plt.title('Change in website/Application design',fontsize=18)
plt.show()

# %% [markdown]
# ##### Observation:
#         Amazon changes their website and application design frequently with respect to different promotions/offers and sale.

# %%
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sns.countplot(x='Website is as efficient as before', data=df,palette='spring')

plt.title('Website is as efficient as before',fontsize=18)
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sns.countplot(x='Which of the Indian online retailer would you recommend to a friend?', data=df,palette='autumn')

plt.title('Which of the Indian online retailer would you recommend to a friend?',fontsize=18)
plt.show()

# %% [markdown]
# ##### Observation:
#         Amazon is the first most recommended application and after that FlipKart is recommended application as compared
#         to others.

# %% [markdown]
# ### Based on E-retail factors for customer activation and retention Amazon is most reliable, trustworthy website for online shopping and fulfill all the requirements of customer .
#
# ### FlipKart is the second most used application for online shopping which fulfills customer needs.
